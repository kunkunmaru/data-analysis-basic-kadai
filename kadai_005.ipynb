# %% [markdown]
# <a href="https://colab.research.google.com/github/kunkunmaru/data-analysis-basic-kadai/blob/main/kadai_005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2,3, tight_layout=True)

#1個目のグラフ
y0 = [1,2,-5,2]
axes[0,0].plot(y0)

#２個目のグラフ
x1 = np.linspace(0,10,100)
y1 = 2 + 2 * np.sin(2*x1)
axes[0,1].plot(x1, y1, linewidth=2.0)
axes[0,1].set(xlim=(0,10), xticks=np.arange(0,10),
              ylim=(-1,5), yticks=np.arange(-1,6))
axes[0,1].plot()

#３個目のグラフ
x3 = np.random .normal(15,5,2000)
plt.xlim(-10, 40)
axes[0,2].hist(x3, bins=10)

#4個目のグラフ
np.random.seed(3)
x4 = 4 + np.random.normal(0,2,60)
y4 = 4 + np.random.normal(0,2,len(x4))
axes[1,0].scatter(x4,y4)
